# %%
import cv2
import os
import numpy as np
import skimage.feature
import matplotlib.pyplot as plt
import pandas as pd
from random import shuffle 
import pickle
# %matplotlib inline

# %%
print (os.getcwd())
# Out:
# /Users/Kishor/Documents/NOAA-SeaLions

# %%
train_path = "data/TrainSmall2/Train/"
train_dotted_path = "data/TrainSmall2/TrainDotted/"
train_blob_path = "data/TrainSmall2/TrainBlob/"
file_names = os.listdir(train_path)

# %%
def filter_image_files(file_names):
    for f in file_names: 
        if f.endswith('.jpg'):
            pass
        else:
            file_names.remove(f)

# %%
file_names
# Out:
# ['41.jpg',
#  '42.jpg',
#  '43.jpg',
#  '44.jpg',
#  '45.jpg',
#  '46.jpg',
#  '47.jpg',
#  '48.jpg',
#  '49.jpg',
#  '50.jpg']

# %% [markdown]
# ### Sample Images

# %%
img = cv2.imread(train_path + file_names[0])
print (img.shape)
plt.imshow(img)
plt.show()
# Out:
# (3328, 4992, 3)

# %%
img = cv2.imread(train_blob_path + file_names[0])
print (img.shape)
plt.imshow(img)
plt.show()
# Out:
# (3328, 4992, 3)

# %%
# 3328, 4992, 3
def normalize(x): 
    return (x - float(np.min(x))) / (float(np.max(x)) - float(np.min(x)))

# %%
def resize(img, size): 
    return cv2.resize(img, size)

# %%
file_name = file_names[0]
img_1 = cv2.imread(train_path + file_name)
img_2 = cv2.imread(train_blob_path + file_name)

img_1 = normalize(img_1)
img_1 = resize(img_1, (4992,3328))
plt.imshow(img_1)
plt.show()

img_2 = normalize(img_2)
img_2 = resize(img_2, (4992,3328))
plt.imshow(img_2)
plt.show()

# %%
# def preprocess_and_save(train_path, train_blob_path): 
def preprocess(train_path, train_blob_path): 
    
    file_names = os.listdir(train_path)
    filter_image_files(file_names)
    shuffle(file_names)
    
    validation_count = int(len(file_names) * 0.1) 
    
    x = [] 
    y = [] 
    
    for f in file_names: 
        img_1 = cv2.imread(train_path + f)
        x.append(resize(img_1, (4992,3328)))
        
        img_2 = cv2.imread(train_blob_path + f)
        y.append(resize(img_2, (4992,3328)))
        
    np_x = np.array(x)
    np_y = np.array(y) 
    
    np_x = normalize(np_x)
    np_y = normalize(np_y)
        
    train_x = np_x[:-validation_count]
    train_y = np_y[:-validation_count]
    valid_x = np_x[-validation_count:]
    valid_y = np_y[-validation_count:]
    
#     print (train_x.shape)
#     print (train_y.shape)
#     print (valid_x.shape)
#     print (valid_y.shape)
#     pickle.dump((train_x, train_y), open('train.p', 'wb'))
#     pickle.dump((valid_x, valid_y), open('valid.p', 'wb'))

    return (train_x, train_y, valid_x, valid_y)

# %%
preprocess_and_save(train_path, train_blob_path)
# Out:
# 1
# (9, 3328, 4992, 3)
# (9, 3328, 4992, 3)
# (1, 3328, 4992, 3)
# (1, 3328, 4992, 3)
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-59-52225ea39f35> in <module>()
# ----> 1 preprocess_and_save(train_path, train_blob_path)
#
# <ipython-input-58-22723da3a5b7> in preprocess_and_save(train_path, train_blob_path)
#      34     print (valid_y.shape)
#      35
# ---> 36     pickle.dump((train_x, train_y), open('train.p', 'wb'))
#      37     pickle.dump((valid_x, valid_y), open('valid.p', 'wb'))
#
# OSError: [Errno 22] Invalid argument
