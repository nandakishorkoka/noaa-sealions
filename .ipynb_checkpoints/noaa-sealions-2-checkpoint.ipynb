# %%
import cv2
import os
import numpy as np
import skimage.feature
import matplotlib.pyplot as plt
import pandas as pd
from random import shuffle 
import pickle
import csv 
# %matplotlib inline

# %%
print (os.getcwd())
# Out:
# /home/ubuntu/pynb/noaa-sealions

# %%
data_path = "/home/ubuntu/pynb/noaa-sealions/data/"
train_path = "/home/ubuntu/pynb/noaa-sealions/data/Train/"
train_dotted_path = "/home/ubuntu/pynb/noaa-sealions/data/TrainDotted/"
train_blob_path = "/home/ubuntu/pynb/noaa-sealions/data/TrainBlob/"

# %%
mismatch_file = open(data_path + 'MismatchedTrainImages.txt', 'rt')
mismatch_ids = mismatch_file.read().strip().split('\n')
mismatch_ids.remove('train_id')
mismatch_ids = [int(x) for x in mismatch_ids]
print (mismatch_ids)
# Out:
# [3, 7, 9, 21, 30, 34, 71, 81, 89, 97, 151, 184, 215, 234, 242, 268, 290, 311, 331, 344, 380, 384, 406, 421, 469, 475, 490, 499, 507, 530, 531, 605, 607, 614, 621, 638, 644, 687, 712, 721, 767, 779, 781, 794, 800, 811, 839, 840, 869, 882, 901, 903, 905, 909, 913, 927, 946]

# %%
def filter_image_files(file_names):
    removes = []
    for f in file_names:
        if f.endswith('.jpg'):
            name,ext = f.split('.')
            if int(name) in mismatch_ids: 
                removes.append(f)
        else:
            removes.append(f) 
    for f in removes: 
        file_names.remove(f) 
        
file_names = os.listdir(train_path)
filter_image_files(file_names)

# %% [markdown]
# ### Sample Images

# %%
img = cv2.imread(train_path + file_names[0])
print (img.shape)
plt.imshow(img)
plt.show()
# Out:
# (3744, 5616, 3)

# %%
img = cv2.imread(train_blob_path + file_names[0])
print (img.shape)
plt.imshow(img)
plt.show()
# Out:
# (3744, 5616, 3)

# %%
# 3328, 4992, 3
def normalize(x): 
    return (x - float(np.min(x))) / (float(np.max(x)) - float(np.min(x)))

# %%
def resize_1(img, size): 
    return cv2.resize(img, size) 

def resize_2(img, fx, fy): 
    return cv2.resize(img, None, fx=fx, fy=fy)

# %%
img_rows = 400 
img_cols = 400

# %%
file_name = file_names[0]
img_1 = cv2.imread(train_path + file_name)
img_2 = cv2.imread(train_blob_path + file_name)

img_1 = normalize(img_1)
img_1 = resize_1(img_1, (img_cols,img_rows))
plt.imshow(img_1)
plt.show()

img_2 = normalize(img_2)
img_2 = resize_1(img_2, (img_cols,img_rows))
plt.imshow(img_2)
plt.show()

# %%
# def preprocess_and_save(train_path, train_blob_path): 
def preprocess(train_path, train_blob_path): 
    
    file_names = os.listdir(train_path)
    filter_image_files(file_names)
    shuffle(file_names)
    
    validation_count = int(len(file_names) * 0.1) 
    
    x = [] 
    y = [] 
    
    for f in file_names: 
        img_1 = cv2.imread(train_path + f)
        x.append(resize_1(img_1, (img_cols,img_rows)))
        
        img_2 = cv2.imread(train_blob_path + f)
        y.append(resize_1(img_2, (img_cols,img_rows)))        
        
    np_x = np.array(x)
    np_y = np.array(y) 
    
    np_x = normalize(np_x)
        
    train_x = np_x[:-validation_count]
    train_y = np_y[:-validation_count]
    valid_x = np_x[-validation_count:]
    valid_y = np_y[-validation_count:]
    
    print (train_x.shape)
    print (train_y.shape)
    print (valid_x.shape)
    print (valid_y.shape)

    return (train_x, train_y, valid_x, valid_y)

# %%
train_x, train_y, valid_x, valid_y = preprocess(train_path, train_blob_path)
# Out:
# (802, 400, 400, 3)
# (802, 400, 400, 3)
# (89, 400, 400, 3)
# (89, 400, 400, 3)

# %%
plt.imshow(train_x[1])
plt.show()

plt.imshow(train_y[1])
plt.show()

# %% [markdown]
# ### Neural Network

# %%
import keras
from keras.models import Sequential, load_model
from keras.models import Model
from keras.layers import Input, concatenate, Dense, Dropout, Activation, Flatten, Conv2D, MaxPooling2D, Lambda, Cropping2D, Conv2DTranspose, UpSampling2D
from keras.utils import np_utils
from keras import backend as K
from keras import optimizers
# Out:
# Using TensorFlow backend.

# %%
smooth = 1.

def dice_coef(y_true, y_pred):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    return (2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)


def dice_coef_loss(y_true, y_pred):
    return -dice_coef(y_true, y_pred)

# %%
img_rows = 400 
img_cols = 400 
img_depth = 3

inputs = Input((img_rows, img_cols, img_depth))

conv1 = Conv2D(32, (3, 3), activation='relu', padding='same')(inputs)
conv1 = Conv2D(32, (3, 3), activation='relu', padding='same')(conv1)
pool1 = MaxPooling2D(pool_size=(2, 2))(conv1)

conv2 = Conv2D(64, (3, 3), activation='relu', padding='same')(pool1)
conv2 = Conv2D(64, (3, 3), activation='relu', padding='same')(conv2)
pool2 = MaxPooling2D(pool_size=(2, 2))(conv2)

conv3 = Conv2D(128, (3, 3), activation='relu', padding='same')(pool2)
conv3 = Conv2D(128, (3, 3), activation='relu', padding='same')(conv3)
pool3 = MaxPooling2D(pool_size=(2, 2))(conv3)

conv4 = Conv2D(256, (3, 3), activation='relu', padding='same')(pool3)
conv4 = Conv2D(256, (3, 3), activation='relu', padding='same')(conv4)
pool4 = MaxPooling2D(pool_size=(2, 2))(conv4)

conv5 = Conv2D(512, (3, 3), activation='relu', padding='same')(pool4)
conv5 = Conv2D(512, (3, 3), activation='relu', padding='same')(conv5)

up6 = concatenate([Conv2DTranspose(256, (2, 2), strides=(2, 2), padding='same')(conv5), conv4], axis=3)
conv6 = Conv2D(256, (3, 3), activation='relu', padding='same')(up6)
conv6 = Conv2D(256, (3, 3), activation='relu', padding='same')(conv6)

up7 = concatenate([Conv2DTranspose(128, (2, 2), strides=(2, 2), padding='same')(conv6), conv3], axis=3)
conv7 = Conv2D(128, (3, 3), activation='relu', padding='same')(up7)
conv7 = Conv2D(128, (3, 3), activation='relu', padding='same')(conv7)

up8 = concatenate([Conv2DTranspose(64, (2, 2), strides=(2, 2), padding='same')(conv7), conv2], axis=3)
conv8 = Conv2D(64, (3, 3), activation='relu', padding='same')(up8)
conv8 = Conv2D(64, (3, 3), activation='relu', padding='same')(conv8)

up9 = concatenate([Conv2DTranspose(32, (2, 2), strides=(2, 2), padding='same')(conv8), conv1], axis=3)
conv9 = Conv2D(32, (3, 3), activation='relu', padding='same')(up9)
conv9 = Conv2D(32, (3, 3), activation='relu', padding='same')(conv9)

conv10 = Conv2D(3, (1, 1), activation='sigmoid')(conv9)

model = Model(inputs=[inputs], outputs=[conv10])
# model.compile(optimizer=optimizers.Adam(lr=1e-3), loss='mse', metrics=['accuracy'])    

model.compile(optimizer=optimizers.Adam(lr=1e-5), loss=dice_coef_loss, metrics=[dice_coef])

# %%
model.fit(train_x, train_y, batch_size=5, epochs=75)
# Out:
# Epoch 1/75
# 802/802 [==============================] - 150s - loss: -0.2105 - dice_coef: 0.2105
# Epoch 2/75
# 802/802 [==============================] - 143s - loss: -0.2396 - dice_coef: 0.2396
# Epoch 3/75
# 802/802 [==============================] - 144s - loss: -0.2615 - dice_coef: 0.2615
# Epoch 4/75
# 802/802 [==============================] - 144s - loss: -0.2799 - dice_coef: 0.2799
# Epoch 5/75
# 802/802 [==============================] - 144s - loss: -0.2857 - dice_coef: 0.2857
# Epoch 6/75
# 802/802 [==============================] - 143s - loss: -0.3484 - dice_coef: 0.3484
# Epoch 7/75
# 802/802 [==============================] - 143s - loss: -0.4050 - dice_coef: 0.4050
# Epoch 8/75
# 802/802 [==============================] - 143s - loss: -0.4672 - dice_coef: 0.4672
# Epoch 9/75
# 802/802 [==============================] - 143s - loss: -0.4703 - dice_coef: 0.4703
# Epoch 10/75
# 802/802 [==============================] - 143s - loss: -0.4916 - dice_coef: 0.4916
# ...

# %%
s = np.array(range(-200,205,5)) 
for i in range(20): 
    shift_x = np.random.choice(s, size=1, replace=False)
    shift_y = np.random.choice(s, size=1, replace=False)

    M = np.float32([[1,0,shift_x],[0,1,shift_y]])
    img_rows = 400 
    img_cols = 400 
    train_ax = [] 
    train_ay = [] 

    for _x, _y in zip(train_x, train_y): 
        train_ax.append(cv2.warpAffine(_x, M, (img_cols,img_rows)))
        train_ay.append(cv2.warpAffine(_y, M, (img_cols,img_rows)))

    train_ax = np.array(train_ax)
    train_ay = np.array(train_ay)         
    model.fit(train_ax, train_ay, batch_size=5, epochs=5)
# Out:
# Epoch 1/5
# 802/802 [==============================] - 143s - loss: -1.0432 - dice_coef: 1.0432
# Epoch 2/5
# 802/802 [==============================] - 144s - loss: -1.0405 - dice_coef: 1.0405
# Epoch 3/5
# 802/802 [==============================] - 144s - loss: -1.0578 - dice_coef: 1.0578
# Epoch 4/5
# 802/802 [==============================] - 144s - loss: -1.0509 - dice_coef: 1.0509
# Epoch 5/5
# 802/802 [==============================] - 144s - loss: -1.0477 - dice_coef: 1.0477
# Epoch 1/5
# 802/802 [==============================] - 144s - loss: -1.0291 - dice_coef: 1.0291
# Epoch 2/5
# 802/802 [==============================] - 144s - loss: -1.0401 - dice_coef: 1.0401
# Epoch 3/5
# 802/802 [==============================] - 144s - loss: -1.0465 - dice_coef: 1.0465
# Epoch 4/5
# 802/802 [==============================] - 144s - loss: -1.0632 - dice_coef: 1.0632
# Epoch 5/5
# 802/802 [==============================] - 144s - loss: -1.0596 - dice_coef: 1.0596
# Epoch 1/5
# ...

# %%
from keras.models import load_model
model.save('full_conv_model.m')  

# returns a compiled model
# model = load_model('full_conv_model.m')
# full_conv_model = load_model('full_conv_model.m', custom_objects={"dice_coef_loss":dice_coef_loss, "dice_coef": dice_coef})

# %%
score = model.evaluate(valid_x, valid_y, batch_size=1)
# Out:
# 89/89 [==============================] - 5s

# %%
score
# Out:
# [-0.98248460609048904, 0.98248460609048904]

# %%
res = model.predict(train_x[0:5], batch_size=1)

# %%
len(res)
# Out:
# 5

# %%
plt.imshow(res[1])
plt.show()

# %%
plt.imshow(train_x[1])
plt.show()

# %%
# def preprocess_and_save(train_path, train_blob_path): 
def final_preprocess(train_path): 
    
    file_names = os.listdir(train_path)
    filter_image_files(file_names)
    shuffle(file_names)

    counts = dict()
    with open(train_path + 'train.csv') as csvfile: 
        next(csvfile) 
        reader = csv.reader(csvfile)
        for row in reader: 
            counts[int(row[0])] = row[1:]

    y = []
    for f in file_names: 
        name,ext = f.split('.')
        y.append(counts[int(name)])
    y = np.array(y,dtype=np.int)  
    
    
    validation_count = int(len(file_names) * 0.1) 
    
    x = [] 
    
    for f in file_names: 
        img_1 = cv2.imread(train_path + f)
        img_1 = resize_1(img_1, (400,400))
        res = model.predict(np.array([img_1]), batch_size=1)
        x.append(res[0])
                
    x = np.array(x)
    x = normalize(x)
                
    train_x = x[:-validation_count]
    train_y = y[:-validation_count]
    valid_x = x[-validation_count:]
    valid_y = y[-validation_count:]
    
    return (train_x, train_y, valid_x, valid_y)

# %%
final_train_x, final_train_y, final_valid_x, final_valid_y = final_preprocess(train_path)

# %%
final_model = Sequential()

final_model.add(Conv2D(  32, (3, 3), activation='relu', padding='same', input_shape=(400, 400, 3)))
final_model.add(Conv2D(  32, (3, 3), activation='relu', padding='same', input_shape=(400, 400, 3)))
final_model.add(MaxPooling2D(pool_size=(2,2)))
final_model.add(Conv2D(  64, (3, 3), activation='relu', padding='same'))
final_model.add(Conv2D(  64, (3, 3), activation='relu', padding='same'))
final_model.add(MaxPooling2D(pool_size=(2,2)))
final_model.add(Conv2D(  128, (3, 3), activation='relu', padding='same'))
final_model.add(Conv2D(  128, (3, 3), activation='relu', padding='same'))
final_model.add(MaxPooling2D(pool_size=(2,2)))
final_model.add(Conv2D(  256, (3, 3), activation='relu', padding='same'))
final_model.add(Conv2D(  256, (3, 3), activation='relu', padding='same'))
final_model.add(MaxPooling2D(pool_size=(2,2)))
final_model.add(Conv2D(  512, (3, 3), activation='relu', padding='same'))
final_model.add(Conv2D(  512, (3, 3), activation='relu', padding='same'))
final_model.add(MaxPooling2D(pool_size=(2,2)))

final_model.add(Flatten())

final_model.add(Dense(512, activation='relu'))
final_model.add(Dropout(0.2))
final_model.add(Dense( 64, activation='relu'))
final_model.add(Dropout(0.2))
final_model.add(Dense(  5, activation='linear'))

final_model.compile(loss='mse', optimizer=optimizers.Adam(lr=1e-5), metr)
final_model.fit(final_train_x, final_train_y, batch_size=8, epochs=25, verbose=2)
# Out:
# Epoch 1/25
# 55s - loss: 1929.7933
# Epoch 2/25
# 54s - loss: 1610.3223
# Epoch 3/25
# 55s - loss: 1558.3042
# Epoch 4/25
# 54s - loss: 1508.4385
# Epoch 5/25
# 54s - loss: 1407.5315
# Epoch 6/25
# 54s - loss: 1360.8058
# Epoch 7/25
# 54s - loss: 1234.0089
# Epoch 8/25
# 54s - loss: 1281.0801
# Epoch 9/25
# 54s - loss: 1194.9895
# Epoch 10/25
# 54s - loss: 1250.6391
# Epoch 11/25
# 54s - loss: 1205.3866
# Epoch 12/25
# 54s - loss: 1180.6783
# Epoch 13/25
# 54s - loss: 1105.5175
# Epoch 14/25
# 54s - loss: 1118.0513
# Epoch 15/25
# 54s - loss: 1105.8910
# Epoch 16/25
# 54s - loss: 1101.8780
# Epoch 17/25
# 54s - loss: 1055.1964
# Epoch 18/25
# 54s - loss: 1167.5226
# Epoch 19/25
# 54s - loss: 1044.5963
# Epoch 20/25
# 54s - loss: 1098.5499
# Epoch 21/25
# 54s - loss: 997.8111
# Epoch 22/25
# 54s - loss: 952.2968
# Epoch 23/25
# 54s - loss: 955.2359
# Epoch 24/25
# 54s - loss: 943.0694
# Epoch 25/25
# 54s - loss: 930.0157

# %%
s = np.array(range(-200,205,5)) 
for i in range(20): 
    shift_x = np.random.choice(s, size=1, replace=False)
    shift_y = np.random.choice(s, size=1, replace=False)

    M = np.float32([[1,0,shift_x],[0,1,shift_y]])
    img_rows = 400 
    img_cols = 400 
    final_train_ax = [] 

    for _x in final_train_x: 
        final_train_ax.append(cv2.warpAffine(_x, M, (img_cols,img_rows)))
        
    final_train_ax = np.array(final_train_ax)
    final_model.fit(final_train_ax, final_train_y, batch_size=16, epochs=5, verbose=2)
# Out:
# Epoch 1/5
# 54s - loss: 1653.0708
# Epoch 2/5

# %%
header = tuple(['test_id','adult_males','subadult_males','adult_females','juveniles','pups'])
with open('submission.csv', 'wt') as csvfile:
    csvwriter = csv.writer(csvfile, quoting=csv.QUOTE_MINIMAL)
    csvwriter.writerow(header)
    for f in file_names: 
        try: 
            tid, text = f.split('.')
            x = []
            img = cv2.imread(test_path + f)
            x.append(resize_1(img, (400,400))) 
            x = np.array(x) 
            vals = final_model.predict(x) 
            vals = vals[0].astype(np.int).tolist()
            
            for i in range(len(vals)): 
                if vals[i] < 0: 
                    vals[i] *= -1
            
            res = tuple([int(tid)] + vals) 
            csvwriter.writerow(res)
        except Exception as e: 
            pass
